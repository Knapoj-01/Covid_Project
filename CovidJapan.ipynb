# %%
import matplotlib.pyplot as plt
import pandas as pd
import Covid

# %%
data = pd.read_csv('Data/Japan_2.csv')
a = Covid.SIR_Model(data, 40000)
a.computeIC(14,16,2)
Ix1, Iy1 = a.predictI(1000,[1, 150])
fig, ax2 = plt.subplots()
ax2.plot(Ix1, Iy1)
ax2.scatter(a.getData("day")[1:150], a.getData("infecteds")[1:150], 0.8)
a.report()
# Out:
# รายงานผลการพยากรณ์โรคโควิด
# วันที่-เวลาพยากรณ์: 20-05-2021 17:27:41
# a = 4.47e-06
# b = 7.14e-02
# rho = 1.60e+04
# ic = -1.29e+05
# วันที่ใช้คำนวณเงื่อนไขเริ่มต้น คือวันที่ 16 ของการระบาด

# %%
b = Covid.SIRD_Model(data, 6000000)
b.computeIC(15,5,65,2)
Ix1, Iy1 = b.predictI(1000,[1, 385])
c = Covid.SIRD_Model(data, 45000000)
c.computeIC(15,6,200,2)
Ix2, Iy2 = c.predictI(1000,[1, 385])
fig, ax2 = plt.subplots()
ax2.plot(Ix1, Iy1, Ix2,Iy2)
ax2.scatter(b.getData("day")[1:380], b.getData("infecteds")[1:380], 0.8)
b.report()
# Out:
# รายงานผลการพยากรณ์โรคโควิด
# วันที่-เวลาพยากรณ์: 15-05-2021 20:37:58
# a = 1.54e-08
# b = 6.67e-02
# rho = 4.32e+06
# ic = -6.14e+07
# วันที่ใช้คำนวณเงื่อนไขเริ่มต้น คือวันที่ 65 ของการระบาด
